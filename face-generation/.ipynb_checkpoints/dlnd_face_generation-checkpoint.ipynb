# %% [markdown]
# # 人脸生成（Face Generation）
# 在该项目中，你将使用生成式对抗网络（Generative Adversarial Nets）来生成新的人脸图像。
# ### 获取数据
# 该项目将使用以下数据集：
# - MNIST
# - CelebA
#
# 由于 CelebA 数据集比较复杂，而且这是你第一次使用 GANs。我们想让你先在 MNIST 数据集上测试你的 GANs 模型，以让你更快的评估所建立模型的性能。
#
# 如果你在使用 [FloydHub](https://www.floydhub.com/), 请将 `data_dir` 设置为 "/input" 并使用 [FloydHub data ID](http://docs.floydhub.com/home/using_datasets/) "R5KrjnANiKVhLWAkpXhNBe".

# %%
data_dir = './data'

# FloydHub - Use with data ID "R5KrjnANiKVhLWAkpXhNBe"
#data_dir = '/input'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper

helper.download_extract('mnist', data_dir)
helper.download_extract('celeba', data_dir)
# Out:
# Found mnist Data
# Found celeba Data

# %% [markdown]
# ## 探索数据（Explore the Data）
# ### MNIST
# [MNIST](http://yann.lecun.com/exdb/mnist/) 是一个手写数字的图像数据集。你可以更改 `show_n_images` 探索此数据集。

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
import os
from glob import glob
from matplotlib import pyplot

mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'mnist/*.jpg'))[:show_n_images], 28, 28, 'L')
pyplot.imshow(helper.images_square_grid(mnist_images, 'L'), cmap='gray')

# %% [markdown]
# ### CelebA
# [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) 是一个包含 20 多万张名人图片及相关图片说明的数据集。你将用此数据集生成人脸，不会用不到相关说明。你可以更改 `show_n_images` 探索此数据集。

# %%
show_n_images = 25

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
mnist_images = helper.get_batch(glob(os.path.join(data_dir, 'img_align_celeba/*.jpg'))[:show_n_images], 28, 28, 'RGB')
pyplot.imshow(helper.images_square_grid(mnist_images, 'RGB'))

# %% [markdown]
# ## 预处理数据（Preprocess the Data）
# 由于该项目的重点是建立 GANs 模型，我们将为你预处理数据。
#
# 经过数据预处理，MNIST 和 CelebA 数据集的值在 28×28 维度图像的 [-0.5, 0.5] 范围内。CelebA 数据集中的图像裁剪了非脸部的图像部分，然后调整到 28x28 维度。
#
# MNIST 数据集中的图像是单[通道](https://en.wikipedia.org/wiki/Channel_(digital_image%29)的黑白图像，CelebA 数据集中的图像是 [三通道的 RGB 彩色图像](https://en.wikipedia.org/wiki/Channel_(digital_image%29#RGB_Images)。
#
# ## 建立神经网络（Build the Neural Network）
# 你将通过部署以下函数来建立 GANs 的主要组成部分:
# - `model_inputs`
# - `discriminator`
# - `generator`
# - `model_loss`
# - `model_opt`
# - `train`
#
# ### 检查 TensorFlow 版本并获取 GPU 型号
# 检查你是否使用正确的 TensorFlow 版本，并获取 GPU 型号

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.0.0
# D:\anaconda3\envs\py3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: No GPU found. Please use a GPU to train your neural network.

# %% [markdown]
# ### 输入（Input）
# 部署 `model_inputs` 函数以创建用于神经网络的 [占位符 (TF Placeholders)](https://www.tensorflow.org/versions/r0.11/api_docs/python/io_ops/placeholders)。请创建以下占位符：
# - 输入图像占位符: 使用 `image_width`，`image_height` 和 `image_channels` 设置为 rank 4。
# - 输入 Z 占位符: 设置为 rank 2，并命名为 `z_dim`。
# - 学习速率占位符: 设置为 rank 0。
#
# 返回占位符元组的形状为 (tensor of real input images, tensor of z data, learning rate)。

# %%
import problem_unittests as tests

def model_inputs(image_width, image_height, image_channels, z_dim):
    """
    Create the model inputs
    :param image_width: The input image width
    :param image_height: The input image height
    :param image_channels: The number of image channels
    :param z_dim: The dimension of Z
    :return: Tuple of (tensor of real input images, tensor of z data, learning rate)
    """
    # TODO: Implement Function
    input_real = tf.placeholder(tf.float32,(None,image_width,image_height,image_channels),name='input_real')
    input_z = tf.placeholder(tf.float32,(None,z_dim),name='input_z')
    learning_rate = tf.placeholder(tf.float32,name='learning_rate')
    return input_real, input_z, learning_rate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### 辨别器（Discriminator）
# 部署 `discriminator` 函数创建辨别器神经网络以辨别 `images`。该函数应能够重复使用神经网络中的各种变量。 在 [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 中使用 "discriminator" 的变量空间名来重复使用该函数中的变量。
#
# 该函数应返回形如 (tensor output of the discriminator, tensor logits of the discriminator) 的元组。

# %%
def discriminator(images, reuse=False):
    """
    Create the discriminator network
    :param image: Tensor of input image(s)
    :param reuse: Boolean if the weights should be reused
    :return: Tuple of (tensor output of the discriminator, tensor logits of the discriminator)
    建议：

    如果要进一步的提升模型的效率，你可以使用0.8概率的dropout和用Xavier初始化你的权重。

    Xavier可以通过下面的方法实现，在tf.layers.conv2d中，将- tf.contrib.layers.xavier_initializer()传入作为kernel_initializerparameter的值。
    Xavier可以加速你的模型收敛的过程，因为在我们这个例子中，我们故意选择了较小的epoch，鼓励你们能够优化模型达到不错的效果，
    所以如果使用了更好的权重初始化方法，就由可能获得更好的结果。
    其次，Xavier有可能增加模型收敛到更低的loss的可能性。
    Dropout可以通过在每一层的Leaky Relu后面加上加上dropout层（tf.nn.dropout）就好啦
    """
    # TODO: Implement Function
    with tf.variable_scope('discriminator', reuse=reuse):
        # Input layer is 28x28x3   第一层不需要批归一化
        x1 = tf.layers.conv2d(images,64,5,strides=2,padding='same',kernel_initializer=tf.contrib.layers.xavier_initializer())
        relu1 = tf.maximum(0.2*x1,x1)
        relu1 = tf.nn.dropout(relu1,0.8)
        # 14*14*64 now
        
        x2 = tf.layers.conv2d(relu1,128,5,strides=2,padding='same',kernel_initializer=tf.contrib.layers.xavier_initializer())
        bn2 = tf.layers.batch_normalization(x2,training=True)
        relu2 = tf.maximum(0.2*bn2,bn2)
        relu2 = tf.nn.dropout(relu2,0.8)
        #7*7*128 now
        
        x3 = tf.layers.conv2d(relu2,256,5,strides=2,padding='same',kernel_initializer=tf.contrib.layers.xavier_initializer())
        bn3 = tf.layers.batch_normalization(x3,training=True)
        relu3 = tf.maximum(0.2*bn3,bn3)
        relu3 = tf.nn.dropout(relu3,0.8)
        #4*4*256 now
        
        flat = tf.reshape(relu3,(-1,4*4*256))
        logits = tf.layers.dense(flat,1)
        out = tf.sigmoid(logits)
        
        return out, logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(discriminator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### 生成器（Generator）
# 部署 `generator` 函数以使用 `z` 生成图像。该函数应能够重复使用神经网络中的各种变量。
# 在 [`tf.variable_scope`](https://www.tensorflow.org/api_docs/python/tf/variable_scope) 中使用 "generator" 的变量空间名来重复使用该函数中的变量。
#
# 该函数应返回所生成的 28 x 28 x `out_channel_dim` 维度图像。

# %%
def generator(z, out_channel_dim, is_train=True):
    """
    Create the generator network
    :param z: Input z
    :param out_channel_dim: The number of channels in the output image
    :param is_train: Boolean if generator is being used for training
    :return: The tensor output of the generator
    请按照上面discriminator的意见进行改进，这两个部分比较类似，用到的优化方法也较为相同。不过我们不建议在 generator 中使用 dropout

    generation本身是更困难的事情，很多人在应用GAN的时候会有意识的让generator网络更深一些，提升效果。从后面的结果看，你的generator比较弱，
    导致generation loss要高于discrimination loss。建议再增加一到两层deconv layer。
    如果对SAME和VALID两种padding方式还是不太理解，stackoverflow上有一个帖子，通过直观的方式介绍了二者的差异
    https://stackoverflow.com/questions/37674306/what-is-the-difference-between-same-and-valid-padding-in-tf-nn-max-pool-of-t?utm_medium=organic&utm_source=google_rich_qa&utm_campaign=google_rich_qa
    """
    # TODO: Implement Function
    with tf.variable_scope('generator', reuse=not is_train):
        # First fully connected layer
        x = tf.layers.dense(z,2*2*512)
        x1 = tf.reshape(x,(-1,2,2,512))
        bn1 = tf.layers.batch_normalization(x1,training=is_train)
        relu1 = tf.maximum(0.2*bn1,bn1)
        #1*1*512
        
        #x2 = tf.layers.conv2d_transpose(relu1,256,5,strides=2,padding='same')
        #bn2 = tf.layers.batch_normalization(x2,training=is_train)
        #relu2 = tf.maximum(0.2*bn2,bn2)
        #2*2*256 now
        
        x2 = tf.layers.conv2d_transpose(relu1,128,5,strides=2)
        bn2 = tf.layers.batch_normalization(x2,training=is_train)
        relu2 = tf.maximum(0.2*bn2,bn2)
        #7*7*128 now
        
        x3 = tf.layers.conv2d_transpose(relu2,64,5,strides=2,padding='same')
        bn3 = tf.layers.batch_normalization(x3,training=is_train)
        relu3 = tf.maximum(0.2*bn3,bn3)
        #14*14*64 now
        
        # Output layer, 28x28x3
        logits = tf.layers.conv2d_transpose(relu3,out_channel_dim,5,strides=2,padding='same')
        #32*32*output_dim now
        
        out = tf.tanh(logits)
        
        return out
    


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(generator, tf)
# Out:
# Tests Passed

# %% [markdown]
# ### 损失函数（Loss）
# 部署 `model_loss` 函数训练并计算 GANs 的损失。该函数应返回形如 (discriminator loss, generator loss) 的元组。
#
# 使用你已实现的函数：
# - `discriminator(images, reuse=False)`
# - `generator(z, out_channel_dim, is_train=True)`

# %%
def model_loss(input_real, input_z, out_channel_dim):
    """
    Get the loss for the discriminator and generator
    :param input_real: Images from the real dataset
    :param input_z: Z input
    :param out_channel_dim: The number of channels in the output image
    :return: A tuple of (discriminator loss, generator loss)
    为了防止discriminator太强了，同时也为了让它能够更有泛化能力，我们一般会将disc_label_real乘以0.9。这叫做标签的（单侧）平滑化。
    你可以通过labels = tf.ones_like(tensor) * (1 - smooth) 来实现。
    """
    # TODO: Implement Function
    g_model = generator(input_z, out_channel_dim)
    d_model_real, d_logits_real = discriminator(input_real)
    d_model_fake, d_logits_fake = discriminator(g_model, reuse=True)

    d_loss_real = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, labels=tf.ones_like(d_logits_real) * (1 - 0.1)))
    d_loss_fake = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.zeros_like(d_model_fake)))
    g_loss = tf.reduce_mean(
        tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, labels=tf.ones_like(d_model_fake)))

    d_loss = d_loss_real + d_loss_fake

    return d_loss, g_loss


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_loss(model_loss)
# Out:
# Tests Passed

# %% [markdown]
# ### 优化（Optimization）
# 部署 `model_opt` 函数实现对 GANs 的优化。使用 [`tf.trainable_variables`](https://www.tensorflow.org/api_docs/python/tf/trainable_variables) 获取可训练的所有变量。通过变量空间名 `discriminator` 和 `generator` 来过滤变量。该函数应返回形如 (discriminator training operation, generator training operation) 的元组。

# %%
def model_opt(d_loss, g_loss, learning_rate, beta1):
    """
    Get optimization operations
    :param d_loss: Discriminator loss Tensor
    :param g_loss: Generator loss Tensor
    :param learning_rate: Learning Rate Placeholder
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :return: A tuple of (discriminator training operation, generator training operation)
    """
    # TODO: Implement Function
    t_vars = tf.trainable_variables()
    d_vars = [var for var in t_vars if var.name.startswith('discriminator')]
    g_vars = [var for var in t_vars if var.name.startswith('generator')]

    # Optimize
    with tf.control_dependencies(tf.get_collection(tf.GraphKeys.UPDATE_OPS)):
        d_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(d_loss, var_list=d_vars)
        g_train_opt = tf.train.AdamOptimizer(learning_rate, beta1=beta1).minimize(g_loss, var_list=g_vars)

    return d_train_opt, g_train_opt


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_opt(model_opt, tf)
# Out:
# Tests Passed

# %% [markdown]
# ## 训练神经网络（Neural Network Training）
# ### 输出显示
# 使用该函数可以显示生成器 (Generator) 在训练过程中的当前输出，这会帮你评估 GANs 模型的训练程度。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

def show_generator_output(sess, n_images, input_z, out_channel_dim, image_mode):
    """
    Show example output for the generator
    :param sess: TensorFlow session
    :param n_images: Number of Images to display
    :param input_z: Input Z Tensor
    :param out_channel_dim: The number of channels in the output image
    :param image_mode: The mode to use for images ("RGB" or "L")
    """
    cmap = None if image_mode == 'RGB' else 'gray'
    z_dim = input_z.get_shape().as_list()[-1]
    example_z = np.random.uniform(-1, 1, size=[n_images, z_dim])

    samples = sess.run(
        generator(input_z, out_channel_dim, False),
        feed_dict={input_z: example_z})

    images_grid = helper.images_square_grid(samples, image_mode)
    pyplot.imshow(images_grid, cmap=cmap)
    pyplot.show()

# %% [markdown]
# ### 训练
# 部署 `train` 函数以建立并训练 GANs 模型。记得使用以下你已完成的函数：
# - `model_inputs(image_width, image_height, image_channels, z_dim)`
# - `model_loss(input_real, input_z, out_channel_dim)`
# - `model_opt(d_loss, g_loss, learning_rate, beta1)`
#
# 使用 `show_generator_output` 函数显示 `generator` 在训练过程中的输出。
#
# **注意**：在每个批次 (batch) 中运行 `show_generator_output` 函数会显著增加训练时间与该 notebook 的体积。推荐每 100 批次输出一次 `generator` 的输出。

# %%
mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
print(mnist_dataset.shape)
# Out:
# (60000, 28, 28, 1)

# %%
def train(epoch_count, batch_size, z_dim, learning_rate, beta1, get_batches, data_shape, data_image_mode):
    """
    Train the GAN
    :param epoch_count: Number of epochs
    :param batch_size: Batch Size
    :param z_dim: Z dimension
    :param learning_rate: Learning Rate
    :param beta1: The exponential decay rate for the 1st moment in the optimizer
    :param get_batches: Function to get batches
    :param data_shape: Shape of the data
    :param data_image_mode: The image mode to use for images ("RGB" or "L")
    """
    # TODO: Build Model
    input_real,input_z,lr = model_inputs(data_shape[1], data_shape[2],data_shape[3],z_dim)    
    d_loss, g_loss = model_loss(input_real,input_z,data_shape[3])
    d_opt, g_opt = model_opt(d_loss,g_loss, learning_rate, beta1)
    saver = tf.train.Saver()

    #samples, losses = [], []
    steps = 0
    
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        for epoch_i in range(epoch_count):
            for batch_images in get_batches(batch_size):
                # TODO: Train Model
                steps += 1
                """这里由于 generator 的输出应用了tanh，tanh函数输出在-1到1之间，但是batch_images的范围在-0.5到0.5之间，
                所以这个地方需要将real image的范围rescale到-1到1之间，这里可以通过batch_images = batch_images*2来实现，
                这样给discriminator传入的real image 和generator的fake image就在相同的范围了。"""
                batch_images = batch_images*2 
                # Sample random noise for G
                batch_z = np.random.uniform(-1, 1, size=(batch_size, z_dim))

                # Run optimizers
                _ = sess.run(d_opt, feed_dict={input_real: batch_images,input_z: batch_z,lr:learning_rate})
                _ = sess.run(g_opt, feed_dict={input_z: batch_z,input_real: batch_images,lr:learning_rate})
                _ = sess.run(g_opt, feed_dict={input_z: batch_z,input_real: batch_images,lr:learning_rate})#为了增强g，优化两次
                if steps % 10 == 0:
                    # At the end of each epoch, get the losses and print them out
                    train_loss_d = d_loss.eval({input_z: batch_z, input_real: batch_images})
                    train_loss_g = g_loss.eval({input_z: batch_z})

                    print("Epoch {}/{}...".format(epoch_i+1, epochs),
                          "Discriminator Loss: {:.4f}...".format(train_loss_d),
                          "Generator Loss: {:.4f}".format(train_loss_g))
                    # Save losses to view after training
                    #losses.append((train_loss_d, train_loss_g))

                if steps % 100 == 0:
                    _ = show_generator_output(sess,25,input_z,data_shape[3] ,data_image_mode)
                   
        saver.save(sess, './checkpoints/generator.ckpt')

    #with open('samples.pkl', 'wb') as f:
     #   pkl.dump(samples, f)

# %% [markdown]
# ### MNIST
# 在 MNIST 上测试你的 GANs 模型。经过 2 次迭代，GANs 应该能够生成类似手写数字的图像。确保生成器 (generator) 低于辨别器 (discriminator) 的损失，或接近 0。

# %%
batch_size = 64
z_dim = 100
learning_rate = 0.001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 2

mnist_dataset = helper.Dataset('mnist', glob(os.path.join(data_dir, 'mnist/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, mnist_dataset.get_batches,
          mnist_dataset.shape, mnist_dataset.image_mode)
# Out:
# Epoch 1/2... Discriminator Loss: 4.4356... Generator Loss: 0.0670
# Epoch 1/2... Discriminator Loss: 3.7575... Generator Loss: 0.1254
# Epoch 1/2... Discriminator Loss: 1.9671... Generator Loss: 0.3820
# Epoch 1/2... Discriminator Loss: 1.5907... Generator Loss: 0.9513
# Epoch 1/2... Discriminator Loss: 1.6903... Generator Loss: 0.9583
# Epoch 1/2... Discriminator Loss: 1.2220... Generator Loss: 1.9353
# Epoch 1/2... Discriminator Loss: 1.0990... Generator Loss: 0.8540
# Epoch 1/2... Discriminator Loss: 1.6043... Generator Loss: 0.7426
# Epoch 1/2... Discriminator Loss: 1.0748... Generator Loss: 1.3561
# Epoch 1/2... Discriminator Loss: 1.2258... Generator Loss: 1.1511
# Epoch 1/2... Discriminator Loss: 1.3275... Generator Loss: 0.8421
# Epoch 1/2... Discriminator Loss: 1.4484... Generator Loss: 0.7593
# Epoch 1/2... Discriminator Loss: 2.0404... Generator Loss: 0.3292
# Epoch 1/2... Discriminator Loss: 1.7666... Generator Loss: 0.3991
# Epoch 1/2... Discriminator Loss: 1.0656... Generator Loss: 1.0798
# Epoch 1/2... Discriminator Loss: 1.4650... Generator Loss: 1.0115
# Epoch 1/2... Discriminator Loss: 1.0748... Generator Loss: 1.1009
# Epoch 1/2... Discriminator Loss: 1.1884... Generator Loss: 1.2752
# Epoch 1/2... Discriminator Loss: 1.4895... Generator Loss: 1.1400
# Epoch 1/2... Discriminator Loss: 1.5473... Generator Loss: 1.6872
# Epoch 1/2... Discriminator Loss: 1.2331... Generator Loss: 1.4307
# Epoch 1/2... Discriminator Loss: 1.1893... Generator Loss: 0.9870
# Epoch 1/2... Discriminator Loss: 1.4652... Generator Loss: 1.4322
# Epoch 1/2... Discriminator Loss: 0.9743... Generator Loss: 1.2702
# Epoch 1/2... Discriminator Loss: 1.1351... Generator Loss: 1.4192
# Epoch 1/2... Discriminator Loss: 1.3993... Generator Loss: 0.8172
# Epoch 1/2... Discriminator Loss: 1.1760... Generator Loss: 0.9909
# Epoch 1/2... Discriminator Loss: 1.4790... Generator Loss: 1.6144
# Epoch 1/2... Discriminator Loss: 1.4538... Generator Loss: 0.7178
# Epoch 1/2... Discriminator Loss: 1.1672... Generator Loss: 1.1156
# Epoch 1/2... Discriminator Loss: 1.3385... Generator Loss: 0.7924
# Epoch 1/2... Discriminator Loss: 1.2815... Generator Loss: 1.3567
# Epoch 1/2... Discriminator Loss: 1.3925... Generator Loss: 0.9215
# Epoch 1/2... Discriminator Loss: 1.3270... Generator Loss: 0.8031
# Epoch 1/2... Discriminator Loss: 1.3769... Generator Loss: 0.9673
# Epoch 1/2... Discriminator Loss: 0.9342... Generator Loss: 1.3288
# Epoch 1/2... Discriminator Loss: 1.4926... Generator Loss: 0.8609
# Epoch 1/2... Discriminator Loss: 1.1640... Generator Loss: 1.0577
# Epoch 1/2... Discriminator Loss: 1.5371... Generator Loss: 1.4520
# Epoch 1/2... Discriminator Loss: 1.5427... Generator Loss: 0.6086
# Epoch 1/2... Discriminator Loss: 1.1990... Generator Loss: 0.8986
# Epoch 1/2... Discriminator Loss: 1.3588... Generator Loss: 0.9082
# Epoch 1/2... Discriminator Loss: 1.3231... Generator Loss: 1.1281
# Epoch 1/2... Discriminator Loss: 1.5389... Generator Loss: 0.5330
# Epoch 1/2... Discriminator Loss: 1.2000... Generator Loss: 0.9877
# Epoch 1/2... Discriminator Loss: 1.2198... Generator Loss: 0.9683
# Epoch 1/2... Discriminator Loss: 1.4026... Generator Loss: 0.9332
# Epoch 1/2... Discriminator Loss: 1.1973... Generator Loss: 1.0922
# Epoch 1/2... Discriminator Loss: 1.2834... Generator Loss: 1.0964
# Epoch 1/2... Discriminator Loss: 1.2585... Generator Loss: 0.9626
# Epoch 1/2... Discriminator Loss: 1.3604... Generator Loss: 1.2015
# Epoch 1/2... Discriminator Loss: 1.2842... Generator Loss: 0.8709
# Epoch 1/2... Discriminator Loss: 1.2255... Generator Loss: 1.0853
# Epoch 1/2... Discriminator Loss: 1.4218... Generator Loss: 1.1399
# Epoch 1/2... Discriminator Loss: 1.4071... Generator Loss: 0.7931
# Epoch 1/2... Discriminator Loss: 1.3943... Generator Loss: 1.1214
# Epoch 1/2... Discriminator Loss: 1.3947... Generator Loss: 0.6709
# Epoch 1/2... Discriminator Loss: 1.3508... Generator Loss: 0.9532
# Epoch 1/2... Discriminator Loss: 1.4222... Generator Loss: 0.7818
# Epoch 1/2... Discriminator Loss: 1.3519... Generator Loss: 0.9588
# Epoch 1/2... Discriminator Loss: 1.3205... Generator Loss: 0.7260
# Epoch 1/2... Discriminator Loss: 1.2592... Generator Loss: 1.0076
# Epoch 1/2... Discriminator Loss: 1.5681... Generator Loss: 0.7239
# Epoch 1/2... Discriminator Loss: 1.1562... Generator Loss: 1.0265
# Epoch 1/2... Discriminator Loss: 1.4355... Generator Loss: 0.8339
# Epoch 1/2... Discriminator Loss: 1.3434... Generator Loss: 1.0013
# Epoch 1/2... Discriminator Loss: 1.2770... Generator Loss: 0.9556
# Epoch 1/2... Discriminator Loss: 1.5883... Generator Loss: 0.6836
# Epoch 1/2... Discriminator Loss: 1.2540... Generator Loss: 1.1463
# Epoch 1/2... Discriminator Loss: 1.2514... Generator Loss: 1.1427
# Epoch 1/2... Discriminator Loss: 1.4899... Generator Loss: 0.9642
# Epoch 1/2... Discriminator Loss: 1.5012... Generator Loss: 0.8244
# Epoch 1/2... Discriminator Loss: 1.5110... Generator Loss: 0.5838
# Epoch 1/2... Discriminator Loss: 1.3191... Generator Loss: 1.0458
# Epoch 1/2... Discriminator Loss: 1.2737... Generator Loss: 1.2314
# Epoch 1/2... Discriminator Loss: 1.3448... Generator Loss: 0.8741
# Epoch 1/2... Discriminator Loss: 1.2773... Generator Loss: 0.8378
# Epoch 1/2... Discriminator Loss: 1.3117... Generator Loss: 0.8367
# Epoch 1/2... Discriminator Loss: 1.4780... Generator Loss: 0.6387
# Epoch 1/2... Discriminator Loss: 1.3151... Generator Loss: 0.8009
# Epoch 1/2... Discriminator Loss: 1.3355... Generator Loss: 0.8781
# Epoch 1/2... Discriminator Loss: 1.6728... Generator Loss: 0.5355
# Epoch 1/2... Discriminator Loss: 1.2910... Generator Loss: 0.9878
# Epoch 1/2... Discriminator Loss: 1.6095... Generator Loss: 1.9096
# Epoch 1/2... Discriminator Loss: 1.2217... Generator Loss: 0.8024
# Epoch 1/2... Discriminator Loss: 1.4405... Generator Loss: 0.5862
# Epoch 1/2... Discriminator Loss: 1.5850... Generator Loss: 0.7310
# Epoch 1/2... Discriminator Loss: 1.1606... Generator Loss: 1.0965
# Epoch 1/2... Discriminator Loss: 1.3052... Generator Loss: 0.9366
# Epoch 1/2... Discriminator Loss: 1.2441... Generator Loss: 0.6746
# Epoch 1/2... Discriminator Loss: 1.3091... Generator Loss: 0.8631
# Epoch 1/2... Discriminator Loss: 1.3066... Generator Loss: 0.8576
# Epoch 1/2... Discriminator Loss: 1.8539... Generator Loss: 0.3433
# Epoch 2/2... Discriminator Loss: 1.3342... Generator Loss: 0.6820
# Epoch 2/2... Discriminator Loss: 1.1672... Generator Loss: 1.0344
# Epoch 2/2... Discriminator Loss: 1.3431... Generator Loss: 0.6297
# Epoch 2/2... Discriminator Loss: 1.3017... Generator Loss: 0.9086
# Epoch 2/2... Discriminator Loss: 1.2569... Generator Loss: 0.7289
# Epoch 2/2... Discriminator Loss: 1.4635... Generator Loss: 1.0192
# Epoch 2/2... Discriminator Loss: 1.7055... Generator Loss: 1.5589
# Epoch 2/2... Discriminator Loss: 1.4317... Generator Loss: 0.8283
# Epoch 2/2... Discriminator Loss: 1.2285... Generator Loss: 0.8557
# Epoch 2/2... Discriminator Loss: 1.2202... Generator Loss: 0.9956
# Epoch 2/2... Discriminator Loss: 1.4374... Generator Loss: 0.5284
# Epoch 2/2... Discriminator Loss: 1.4539... Generator Loss: 1.4601
# Epoch 2/2... Discriminator Loss: 1.4668... Generator Loss: 0.5923
# Epoch 2/2... Discriminator Loss: 1.2165... Generator Loss: 0.9477
# Epoch 2/2... Discriminator Loss: 1.4592... Generator Loss: 1.2923
# Epoch 2/2... Discriminator Loss: 1.5458... Generator Loss: 0.4768
# Epoch 2/2... Discriminator Loss: 1.2636... Generator Loss: 0.6946
# Epoch 2/2... Discriminator Loss: 1.6893... Generator Loss: 0.3652
# Epoch 2/2... Discriminator Loss: 1.3002... Generator Loss: 0.6179
# Epoch 2/2... Discriminator Loss: 1.3483... Generator Loss: 0.8333
# Epoch 2/2... Discriminator Loss: 2.2315... Generator Loss: 2.1415
# Epoch 2/2... Discriminator Loss: 1.4376... Generator Loss: 0.6582
# Epoch 2/2... Discriminator Loss: 1.3899... Generator Loss: 0.8117
# Epoch 2/2... Discriminator Loss: 1.1963... Generator Loss: 0.8664
# Epoch 2/2... Discriminator Loss: 1.1980... Generator Loss: 1.0593
# Epoch 2/2... Discriminator Loss: 1.5291... Generator Loss: 0.4806
# Epoch 2/2... Discriminator Loss: 1.2990... Generator Loss: 0.8782
# Epoch 2/2... Discriminator Loss: 1.3410... Generator Loss: 0.6536
# Epoch 2/2... Discriminator Loss: 1.4550... Generator Loss: 1.5209
# Epoch 2/2... Discriminator Loss: 1.4394... Generator Loss: 0.6001
# Epoch 2/2... Discriminator Loss: 1.2356... Generator Loss: 0.6913
# Epoch 2/2... Discriminator Loss: 1.4018... Generator Loss: 1.1798
# Epoch 2/2... Discriminator Loss: 1.4217... Generator Loss: 0.6819
# Epoch 2/2... Discriminator Loss: 1.7383... Generator Loss: 0.4153
# Epoch 2/2... Discriminator Loss: 1.4156... Generator Loss: 0.7295
# Epoch 2/2... Discriminator Loss: 1.1667... Generator Loss: 0.9080
# Epoch 2/2... Discriminator Loss: 1.4518... Generator Loss: 0.6135
# Epoch 2/2... Discriminator Loss: 1.2540... Generator Loss: 1.1940
# Epoch 2/2... Discriminator Loss: 1.6833... Generator Loss: 0.4991
# Epoch 2/2... Discriminator Loss: 1.1910... Generator Loss: 1.0160
# Epoch 2/2... Discriminator Loss: 1.3207... Generator Loss: 0.7973
# Epoch 2/2... Discriminator Loss: 1.3634... Generator Loss: 0.6264
# Epoch 2/2... Discriminator Loss: 1.2075... Generator Loss: 0.7761
# Epoch 2/2... Discriminator Loss: 1.2651... Generator Loss: 0.9294
# Epoch 2/2... Discriminator Loss: 1.2028... Generator Loss: 0.7413
# Epoch 2/2... Discriminator Loss: 1.2343... Generator Loss: 1.0562
# Epoch 2/2... Discriminator Loss: 1.7004... Generator Loss: 1.6674
# Epoch 2/2... Discriminator Loss: 1.4258... Generator Loss: 0.5196
# Epoch 2/2... Discriminator Loss: 1.3526... Generator Loss: 0.6933
# Epoch 2/2... Discriminator Loss: 1.3091... Generator Loss: 0.8561
# Epoch 2/2... Discriminator Loss: 1.1972... Generator Loss: 1.0621
# Epoch 2/2... Discriminator Loss: 1.5596... Generator Loss: 1.6575
# Epoch 2/2... Discriminator Loss: 1.8661... Generator Loss: 0.3064
# Epoch 2/2... Discriminator Loss: 1.2161... Generator Loss: 1.1548
# Epoch 2/2... Discriminator Loss: 1.2722... Generator Loss: 0.8798
# Epoch 2/2... Discriminator Loss: 1.5038... Generator Loss: 0.5065
# Epoch 2/2... Discriminator Loss: 1.1701... Generator Loss: 1.4094
# Epoch 2/2... Discriminator Loss: 1.3801... Generator Loss: 0.6237
# Epoch 2/2... Discriminator Loss: 2.2165... Generator Loss: 2.0401
# Epoch 2/2... Discriminator Loss: 1.2338... Generator Loss: 0.9799
# Epoch 2/2... Discriminator Loss: 1.2682... Generator Loss: 0.9786
# Epoch 2/2... Discriminator Loss: 1.1782... Generator Loss: 1.1076
# Epoch 2/2... Discriminator Loss: 1.4052... Generator Loss: 0.9162
# Epoch 2/2... Discriminator Loss: 1.5441... Generator Loss: 0.4293
# Epoch 2/2... Discriminator Loss: 1.1430... Generator Loss: 0.9915
# Epoch 2/2... Discriminator Loss: 1.3881... Generator Loss: 0.8066
# Epoch 2/2... Discriminator Loss: 1.5220... Generator Loss: 1.0894
# Epoch 2/2... Discriminator Loss: 1.2424... Generator Loss: 0.8656
# Epoch 2/2... Discriminator Loss: 1.3188... Generator Loss: 1.3125
# Epoch 2/2... Discriminator Loss: 1.3305... Generator Loss: 0.9224
# Epoch 2/2... Discriminator Loss: 1.3834... Generator Loss: 0.6284
# Epoch 2/2... Discriminator Loss: 1.3798... Generator Loss: 0.7365
# Epoch 2/2... Discriminator Loss: 1.3650... Generator Loss: 1.2117
# Epoch 2/2... Discriminator Loss: 1.1143... Generator Loss: 1.2085
# Epoch 2/2... Discriminator Loss: 1.1667... Generator Loss: 1.2927
# Epoch 2/2... Discriminator Loss: 1.2055... Generator Loss: 0.8266
# Epoch 2/2... Discriminator Loss: 1.3755... Generator Loss: 0.7466
# Epoch 2/2... Discriminator Loss: 1.3265... Generator Loss: 0.6887
# Epoch 2/2... Discriminator Loss: 1.3942... Generator Loss: 0.8688
# Epoch 2/2... Discriminator Loss: 1.3516... Generator Loss: 0.6438
# Epoch 2/2... Discriminator Loss: 1.2547... Generator Loss: 1.2410
# Epoch 2/2... Discriminator Loss: 1.3197... Generator Loss: 1.5104
# Epoch 2/2... Discriminator Loss: 1.1596... Generator Loss: 0.7983
# Epoch 2/2... Discriminator Loss: 1.1568... Generator Loss: 1.3838
# Epoch 2/2... Discriminator Loss: 1.3856... Generator Loss: 0.7280
# Epoch 2/2... Discriminator Loss: 1.1874... Generator Loss: 0.7498
# Epoch 2/2... Discriminator Loss: 1.5338... Generator Loss: 0.6165
# Epoch 2/2... Discriminator Loss: 1.3618... Generator Loss: 0.7591
# Epoch 2/2... Discriminator Loss: 1.3958... Generator Loss: 0.8278
# Epoch 2/2... Discriminator Loss: 1.3031... Generator Loss: 0.9773
# Epoch 2/2... Discriminator Loss: 1.3976... Generator Loss: 0.7049
# Epoch 2/2... Discriminator Loss: 1.3703... Generator Loss: 0.8409
# Epoch 2/2... Discriminator Loss: 1.3341... Generator Loss: 0.8003
# Epoch 2/2... Discriminator Loss: 1.2347... Generator Loss: 0.7073

# %% [markdown]
# ### CelebA
# 在 CelebA 上运行你的 GANs 模型。在一般的GPU上运行每次迭代大约需要 20 分钟。你可以运行整个迭代，或者当 GANs 开始产生真实人脸图像时停止它。

# %%
batch_size = 32
z_dim = 100
learning_rate = 0.001
beta1 = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
epochs = 1

celeba_dataset = helper.Dataset('celeba', glob(os.path.join(data_dir, 'img_align_celeba/*.jpg')))
with tf.Graph().as_default():
    train(epochs, batch_size, z_dim, learning_rate, beta1, celeba_dataset.get_batches,
          celeba_dataset.shape, celeba_dataset.image_mode)
# Out:
# Epoch 1/1... Discriminator Loss: 2.0306... Generator Loss: 3.2660
# Epoch 1/1... Discriminator Loss: 1.3559... Generator Loss: 0.8591
# Epoch 1/1... Discriminator Loss: 3.2135... Generator Loss: 0.6133
# Epoch 1/1... Discriminator Loss: 1.4438... Generator Loss: 0.9206
# Epoch 1/1... Discriminator Loss: 2.4421... Generator Loss: 0.3263
# Epoch 1/1... Discriminator Loss: 1.8466... Generator Loss: 0.5091
# Epoch 1/1... Discriminator Loss: 1.5283... Generator Loss: 0.7676
# Epoch 1/1... Discriminator Loss: 2.0117... Generator Loss: 0.4569
# Epoch 1/1... Discriminator Loss: 1.5445... Generator Loss: 0.9494
# Epoch 1/1... Discriminator Loss: 1.6796... Generator Loss: 0.8655
# Epoch 1/1... Discriminator Loss: 2.2936... Generator Loss: 0.5661
# Epoch 1/1... Discriminator Loss: 2.0180... Generator Loss: 0.4163
# Epoch 1/1... Discriminator Loss: 1.4623... Generator Loss: 0.6304
# Epoch 1/1... Discriminator Loss: 1.6041... Generator Loss: 0.6639
# Epoch 1/1... Discriminator Loss: 1.6244... Generator Loss: 0.8806
# Epoch 1/1... Discriminator Loss: 1.7256... Generator Loss: 0.6034
# Epoch 1/1... Discriminator Loss: 1.4877... Generator Loss: 0.7710
# Epoch 1/1... Discriminator Loss: 1.9355... Generator Loss: 0.5549
# Epoch 1/1... Discriminator Loss: 1.3992... Generator Loss: 0.9497
# Epoch 1/1... Discriminator Loss: 2.2167... Generator Loss: 0.7018
# Epoch 1/1... Discriminator Loss: 1.8634... Generator Loss: 0.5973
# Epoch 1/1... Discriminator Loss: 1.7984... Generator Loss: 0.7495
# Epoch 1/1... Discriminator Loss: 1.5824... Generator Loss: 0.8341
# Epoch 1/1... Discriminator Loss: 1.5519... Generator Loss: 0.6865
# Epoch 1/1... Discriminator Loss: 1.2951... Generator Loss: 0.8364
# Epoch 1/1... Discriminator Loss: 1.4430... Generator Loss: 0.7849
# Epoch 1/1... Discriminator Loss: 1.4293... Generator Loss: 0.8344
# Epoch 1/1... Discriminator Loss: 1.5801... Generator Loss: 0.7723
# Epoch 1/1... Discriminator Loss: 1.8506... Generator Loss: 0.4987
# Epoch 1/1... Discriminator Loss: 1.6359... Generator Loss: 1.1101
# Epoch 1/1... Discriminator Loss: 1.5071... Generator Loss: 0.6073
# Epoch 1/1... Discriminator Loss: 1.4075... Generator Loss: 0.7626
# Epoch 1/1... Discriminator Loss: 2.3675... Generator Loss: 0.4290

# %% [markdown]
# ### 提交项目
# 提交本项目前，确保运行所有 cells 后保存该文件。
#
# 保存该文件为 "dlnd_face_generation.ipynb"， 并另存为 HTML 格式 "File" -> "Download as"。提交项目时请附带 "helper.py" 和 "problem_unittests.py" 文件。
